# %%
from IPython.display import clear_output, Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# from PIL import Image as pil_image

# %%
img = mpimg.imread('target1.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(1, 1))

# [START_Y:END_Y, START_X:END_X]
# (20, 30)
plt.imshow(img[506:526, 60:90])

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(img)

# %%
for i in range(10):
    clear_output()
    img = mpimg.imread('target1.png')
    print(type(img))
#     plt.imshow(img[0][0])
    plt.show()
    input("{}> ".format(i))

# %%
plt.imshow(mpimg.imread('target1.png')[0])
